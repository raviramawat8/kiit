# %% [markdown]
# ### Control Flow Statements

# %% [markdown]
#     1. Conditonal Statements
#         a. if
#         b. if-else
#         c. if-elif-else
#         d. Nested if-else
#         e. if-else ladder or Branching
#
#
#     2. Loops
#         a. While
#         b. for
#
#
#     3. Functional Call
#
#
#     4. Statements
#         a. break
#         b. continue
#         c. pass

# %%
from PIL import Image

# %%
Image.open("Flow_chart.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2712x1130 at 0x27717C4A970>

# %%
#Draw a flow chart for greatest between two nos

# %%
Image.open("flow_g_2nos.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2712x1130 at 0x277182AA400>

# %%
#Task --> Draw a flow chart for greatest between three nos
